# %%
from scipy.optimize import least_squares

# %%
from cosmology import f,j,data
# Out:
# With wiki data cost equals =  0.21900131665664999 | With our approximate 0.11386136722898951
# <img src="data:image/png;base64,..." width="639.0476480687299">
# <img src="data:image/png;base64,..." width="699.0476507935139">

# %%
this = lambda args: f(data[:,0], *args) - data[:,1]

# %%
import numpy as np

# %%
# %timeit least_squares(fun=this,  x0 = np.array([50/70, 0.5]), jac = jac, xtol= 1e-8, method='lm',gtol=0.01)
# Out:
# 39.3 ms ± 53.3 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit least_squares(fun=this,  x0 = np.array([50/70, 0.5]), xtol= 1e-8, method='lm',gtol=0.01)
# Out:
# 36.4 ms ± 456 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
